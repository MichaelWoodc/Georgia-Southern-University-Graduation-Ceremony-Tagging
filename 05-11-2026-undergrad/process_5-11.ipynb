# %% [markdown]
# ## Make it write json and csv every detection, also, make it restart from last position

# %% [markdown]
# ## With status updates

# %%
import cv2
import pytesseract
from pytesseract import Output
import numpy as np
import os
import csv
import json
from skimage.metrics import structural_similarity as ssim
from datetime import timedelta

# ---------------- CONFIG ----------------
VIDEO_FILE = "2026-05-13-graduate.mp4"

START_TIME = "00:38:02"
END_TIME   = "01:12:02"

ANNOTATED_DIR = "annotated"
CSV_FILE = "ocr_results.csv"
JSON_FILE = "ocr_results.json"

os.makedirs(ANNOTATED_DIR, exist_ok=True)

# OCR ROI
X0, Y0 = 250, 520
X1, Y1 = 1920, 1080

# OCR config
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
TESS_CFG = "--psm 6 --oem 3 -l eng"

def ts_to_seconds(ts):
    h, m, s = ts.split(":")
    return int(h)*3600 + int(m)*60 + float(s)

def format_timestamp(seconds):
    h = int(seconds // 3600)
    m = int((seconds % 3600) // 60)
    s = seconds % 60
    return f"{h:02d}:{m:02d}:{s:06.3f}"

# ---------------- RESUME LOGIC ----------------
resume_sec = ts_to_seconds(START_TIME)

if os.path.exists(CSV_FILE):
    with open(CSV_FILE, "r", encoding="utf-8") as f:
        rows = list(csv.reader(f))
        if len(rows) > 1:
            last_ts = rows[-1][0]
            resume_sec = ts_to_seconds(last_ts)
            print(f"Found existing CSV file: {CSV_FILE}")
            print(f"Resuming last location of: {last_ts}")
        else:
            print("CSV exists but contains no detections, starting fresh.")
else:
    print("No CSV found. Starting from beginning.")

# ---------------- VIDEO SETUP ----------------
cap = cv2.VideoCapture(VIDEO_FILE)
fps = cap.get(cv2.CAP_PROP_FPS)

cap.set(cv2.CAP_PROP_POS_MSEC, resume_sec * 1000)

last_roi = None
frame_number = int(resume_sec * fps)

# ---------------- JSON STREAMING SETUP ----------------
json_file = open(JSON_FILE, "a", encoding="utf-8")
if os.path.getsize(JSON_FILE) == 0:
    json_file.write("[\n")
    first_json = True
else:
    json_file.seek(0, os.SEEK_END)
    first_json = False

# ---------------- CSV SETUP ----------------
csv_exists = os.path.exists(CSV_FILE)
csv_file = open(CSV_FILE, "a", newline="", encoding="utf-8")
writer = csv.writer(csv_file)

if not csv_exists:
    writer.writerow(["timestamp", "ocr_text", "confidence"])

# ---------------- MAIN LOOP ----------------
while True:
    ret, frame = cap.read()
    if not ret:
        break

    current_sec = resume_sec + ((frame_number - int(resume_sec * fps)) / fps)
    if current_sec > ts_to_seconds(END_TIME):
        break

    roi = frame[Y0:Y1, X0:X1]

    changed = True
    if last_roi is not None:
        roi_gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
        last_gray = cv2.cvtColor(last_roi, cv2.COLOR_BGR2GRAY)
        roi_gray = cv2.resize(roi_gray, (last_gray.shape[1], last_gray.shape[0]))
        score = ssim(roi_gray, last_gray)
        changed = score < 0.92

    if changed:
        # OCR
        data = pytesseract.image_to_data(roi, config=TESS_CFG, output_type=Output.DICT)
        text = pytesseract.image_to_string(roi, config=TESS_CFG).strip()

        confs = []
        for c in data["conf"]:
            try:
                ci = int(c)
                if ci > 0:
                    confs.append(ci)
            except:
                pass
        avg_conf = sum(confs)/len(confs) if confs else 0.0

        last_roi = roi.copy()

        # Annotated frame
        annotated = frame.copy()
        cv2.rectangle(annotated, (X0, Y0), (X1, Y1), (0,255,0), 3)

        if text:
            y0 = 40
            for line in text.split("\n"):
                cv2.putText(annotated, line, (50, y0),
                            cv2.FONT_HERSHEY_SIMPLEX, 1.0,
                            (0,255,0), 2, cv2.LINE_AA)
                y0 += 40

        # Timestamp in upper-right
        ts_str = format_timestamp(current_sec)
        (tw, th), _ = cv2.getTextSize(ts_str, cv2.FONT_HERSHEY_SIMPLEX, 1.2, 3)
        x = annotated.shape[1] - tw - 50
        y = 50 + th
        cv2.putText(annotated, ts_str, (x, y),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0,255,255), 3, cv2.LINE_AA)

        # Save annotated frame
        ann_path = os.path.join(ANNOTATED_DIR, f"{frame_number:06d}_annotated.jpg")
        cv2.imwrite(ann_path, annotated)

        # CSV write
        writer.writerow([ts_str, text, f"{avg_conf:.2f}"])
        csv_file.flush()

        # JSON write
        entry = {
            "index": str(frame_number),
            "timestamp": ts_str,
            "label": "frame",
            "ocr_text": text,
            "confidence": f"{avg_conf:.2f}"
        }

        if not first_json:
            json_file.write(",\n")
        first_json = False

        json_file.write(json.dumps(entry, indent=2))
        json_file.flush()
        os.fsync(json_file.fileno())

        # ---------------- TERMINAL STATUS UPDATE ----------------
        print(f"[DETECTION] {ts_str} — \"{text}\"")

    frame_number += 1

# Close JSON array
json_file.write("\n]\n")
json_file.close()
csv_file.close()
cap.release()

print("Done.")
# Out:
# Found existing CSV file: ocr_results.csv
# Resuming last location of: 00:39:46.905
# [DETECTION] 00:39:46.905 — "Jhalil Jarid Smith"
# [DETECTION] 00:39:58.250 — "Linea Elizabeth Romano
# Magna Cum Laude"
# [DETECTION] 00:40:08.794 — "Adarryl Montez Ricketson, Jr."
# [DETECTION] 00:40:13.932 — "Noah Carson White"
# [DETECTION] 00:40:26.678 — "Ryan Villeneuve-Schoenberg
# Summa Cum Laude"
# [DETECTION] 00:40:32.451 — "Carly Shea Mccue
# Magna Cum Laude"
# [DETECTION] 00:40:40.225 — "Jennifer Nicole Gonser"
# [DETECTION] 00:40:51.570 — "College of Education"
# [DETECTION] 00:40:54.339 — "Imogene Loretta Messam
# Magna Cum Laude"
# [DETECTION] 00:41:00.078 — "Kimberly Denise Parker
# Magna Cum Laude"
# [DETECTION] 00:41:06.117 — "Faith Rosa Booker"
# [DETECTION] 00:41:11.623 — "Emily Nicole Scarborough"
# [DETECTION] 00:41:17.028 — "Lauren Rebekah Richardson"
# [DETECTION] 00:41:22.734 — "Claire Madeline Garman"
# [DETECTION] 00:41:27.506 — "Logan Matthew Ellis
# Cum Laude"
# [DETECTION] 00:41:33.411 — "Alessa Raquel Giron-Molina
# Summa Cum Laude"
# [DETECTION] 00:41:38.750 — "Lily Karis Melville
# Magna Cum Laude"
# [DETECTION] 00:41:43.688 — "Ansley Morgan Lightner"
# [DETECTION] 00:41:49.027 — "Llola Breez Mitchell
# Summa Cum Laude"
# [DETECTION] 00:41:54.432 — "Julia Lynn Deal"
# [DETECTION] 00:41:59.604 — "Nandi A. Birtha
# Cum Laude"
# [DETECTION] 00:42:11.750 — "Xavianna Brown"
# [DETECTION] 00:42:17.889 — "Laura Victoria Cabral
# Magna Cum Laude"
# [DETECTION] 00:42:23.628 — "Laura Grace Martin"
# [DETECTION] 00:42:29.000 — "Nestor Alonso Barajas-Ruiz
# Summa Cum Laude"
# [DETECTION] 00:42:34.639 — "Susanna M. Wright"
# [DETECTION] 00:42:46.751 — "LaToya Wright Wilson
# Cum Laude"
# [DETECTION] 00:42:55.727 — "Allen E. Paulson College of Engineering and
# Computing"
# [DETECTION] 00:43:00.532 — "Philip Azer
# Magna Cum Laude"
# [DETECTION] 00:43:04.436 — "James Matthew Mixon"
# [DETECTION] 00:43:09.741 — "Vincent Gianfranco Marsan"
# [DETECTION] 00:43:15.847 — "Tuan Minh Hoang"
# [DETECTION] 00:43:27.525 — "Josue Cordero Efre
# Magna Cum Laude"
# [DETECTION] 00:43:33.632 — "Devin Bass"
# [DETECTION] 00:43:39.037 — "Alejandro Jose Giron Molina"
# [DETECTION] 00:43:44.376 — "Nicholas-Paul Alexander Webster"
# [DETECTION] 00:43:49.514 — "Andrew Ryan Medlin
# Cum Laude"
# [DETECTION] 00:43:54.419 — "Alexander J. Azpiazu
# Magna Cum Laude"
# [DETECTION] 00:43:59.424 — "Troy Glenn Johns"
# [DETECTION] 00:44:39.330 — "Jae Hong Kim
# Cum Laude"
# [DETECTION] 00:44:44.869 — "Chukwukelum Williams Okoye"
# [DETECTION] 00:44:50.842 — "Javierre Gabriel Williams"
# [DETECTION] 00:44:58.249 — "Bao Quoc Pham
# Magna Cum Laude"
# [DETECTION] 00:45:03.321 — "Windy Nguyen Pham
# Cum Laude"
# [DETECTION] 00:45:08.526 — "Maisie Xuan Mai Tran"
# [DETECTION] 00:45:13.798 — "Gawain Nathaniel Mendez"
# [DETECTION] 00:45:18.970 — "Michael Leonard Woodcock
# Magna Cum Laude"
# [DETECTION] 00:45:24.275 — "Kaylee B. Mailler
# Magna Cum Laude"
# [DETECTION] 00:45:29.881 — "Brent William Shepherd"
# [DETECTION] 00:45:41.126 — "Lesly Melinda Zetino-Alas"
# [DETECTION] 00:45:48.566 — "College of Science and Mathematics"
# [DETECTION] 00:45:51.970 — "Sophia Castillo-Gomez"
# [DETECTION] 00:45:56.674 — "Katie Nguyen
# Magna Cum Laude"
# [DETECTION] 00:46:13.491 — "Kiara P. Brown
# Magna Cum Laude
# Honors College Scholar"
# [DETECTION] 00:46:19.197 — "Alexander S. Gallerani"
# [DETECTION] 00:46:24.269 — "Brayden Shyann Bailey
# [DETECTION] 00:55:52.803 — "Imani Arissa Cummings"
# [DETECTION] 00:55:58.442 — "Lourdes Angelee Michel-Milian
# Cum Laude"
# [DETECTION] 00:56:04.181 — "Jessica Hansen"
# [DETECTION] 00:56:15.292 — "Holly Renee Webb
# Magna Cum Laude"
# [DETECTION] 00:56:21.499 — "Brooklyn Airiana Dearstyne"
# [DETECTION] 00:56:27.037 — "Rebekah Joanna Gall"
# [DETECTION] 00:56:31.609 — "Meeraben Ajitkumar Patel
# Summa Cum Laude"
# [DETECTION] 00:56:37.615 — "Kristopher Alexander
# Magna Cum Laude"
# [DETECTION] 00:56:42.987 — "Carleigh Catherine Miley
# Magna Cum Laude"
# [DETECTION] 00:56:47.491 — "Quayziona Jzaky’iah Monae Orr Clark
# Magna Cum Laude"
# [DETECTION] 00:56:53.964 — "Madison H. Ballenger
# Summa Cum Laude"
# [DETECTION] 00:57:00.004 — "Charlene Ray"
# [DETECTION] 00:57:21.659 — "Michael Jaron Javier Johnson"
# [DETECTION] 00:57:27.097 — "Nicole A. Lomonaco"
# [DETECTION] 00:57:32.036 — "Emma Elizabeth Saunders"
# [DETECTION] 00:57:36.273 — "Marquisia Iyana Scott"
# [DETECTION] 00:57:45.483 — "LuisMiguel Efrain Santiago"
# [DETECTION] 00:57:50.721 — "Carter Hutton"
# [DETECTION] 00:58:27.258 — "Pamela Abena Kplivi
# Summa Cum Laude
# Honors College Scholar"
# [DETECTION] 00:58:34.131 — "Olivia Hughes
# Cum Laude"
# [DETECTION] 00:58:39.336 — "Sharonna Shanice Ray"
# [DETECTION] 00:59:02.293 — "Abigayle Leigh Whisman"
# [DETECTION] 00:59:07.765 — "Amy Chakoutis
# Cum Laude"
# [DETECTION] 00:59:13.304 — "Abigail Grace Blanda"
# [DETECTION] 00:59:19.376 — "Ni'Kyna Ikyona Bigham"
# [DETECTION] 00:59:32.756 — "Kaydence Alivia Graham"
# [DETECTION] 00:59:39.096 — "Micaela Antoinette Sullivan"
# [DETECTION] 00:59:43.701 — "Ta'Neajah Ra'Niya Campbell
# Magna Cum Laude"
# [DETECTION] 00:59:49.273 — "Danielle Dumadag"
# [DETECTION] 00:59:54.778 — "Daniel Smith
# Magna Cum Laude"
# [DETECTION] 00:59:59.817 — "Matty Layne Lenoir
# Cum Laude"
# [DETECTION] 01:00:04.755 — "Kayla Ann Clarke"
# [DETECTION] 01:00:15.966 — "Mckenzie S. Monterrozo
# Cum Laude"
# [DETECTION] 01:00:21.705 — "Wysenerlie Tucker
# Magna Cum Laude"
# [DETECTION] 01:00:26.477 — "Arielle Marie Gray"
# [DETECTION] 01:00:38.155 — "Waters College of Health Professions"
# [DETECTION] 01:00:41.425 — "Savanna Elizabeth Margarita Nelson
# Cum Laude"
# [DETECTION] 01:00:46.330 — "Noah David Borba"
# [DETECTION] 01:00:58.142 — "Naomi Eva Matrai
# Magna Cum Laude"
# [DETECTION] 01:01:03.047 — "Cameron Pearl Kozlowski
# Cum Laude"
# [DETECTION] 01:01:07.918 — "Anna Westbrook"
# [DETECTION] 01:01:38.415 — "Jazmyn Symone Eldridge"
# [DETECTION] 01:01:43.887 — "Savanna E*Monie Lawrence"
# [DETECTION] 01:01:48.258 — "Ansley Ryenne Vickers
# Summa Cum Laude
# Honors College Scholar"
# [DETECTION] 01:01:54.932 — "Lauren B. Natalie
# Summa Cum Laude"
# [DETECTION] 01:01:59.536 — "Marygrace Elizabeth Westbrook
# Cum Laude"
# [DETECTION] 01:02:04.441 — "Emma Kathryn Hartley
# Cum Laude"
# [DETECTION] 01:02:32.102 — "Reagan Richards
# Summa Cum Laude"
# [DETECTION] 01:02:42.045 — "Gracyn Laurissa Hunt"
# [DETECTION] 01:02:48.018 — "Kaitlyn Anne Peck
# Summa Cum Laude"
# [DETECTION] 01:02:53.290 — "Madison Roxie Prince"
# [DETECTION] 01:03:05.035 — "Makayla Brooke Priddy
# Summa Cum Laude"
# [DETECTION] 01:03:09.807 — "Trenity D'asiyah Collins"
# [DETECTION] 01:03:14.745 — "Joshua Grantham
# Cum Laude"
# [DETECTION] 01:03:20.484 — "Anna Ayers
# Magna Cum Laude"
# [DETECTION] 01:03:24.955 — "Trinity Paige Heindl
# Summa Cum Laude"
# [DETECTION] 01:03:30.027 — "Brooklyn Rose Torres
# Magna Cum Laude"
# [DETECTION] 01:03:35.065 — "Victoria Jasmine Morton-Mijares"
# [DETECTION] 01:03:40.604 — "Chloee A. Hickman"
# [DETECTION] 01:03:53.083 — "Faith V. Brown
# Cum Laude"
# [DETECTION] 01:04:03.393 — "Niyuna Makayla Biece Robinson"
# [DETECTION] 01:04:08.799 — "Amber Pele’ White
# Magna Cum Laude"
# [DETECTION] 01:04:14.171 — "Sabrina Alexis Messer"
# [DETECTION] 01:04:20.510 — "Leonard Bernard Russell
# Magna Cum Laude"
# [DETECTION] 01:04:25.916 — "Emma Marie Cruz"
# [DETECTION] 01:04:35.259 — "Adam Marcum Wentz
# Cum Laude"
# [DETECTION] 01:04:40.898 — "Jesuspersona Sungjong Song"
# [DETECTION] 01:04:46.536 — "Courtney Sky Higginbotham
# Cum Laude"
# [DETECTION] 01:04:52.342 — "Shanice Chantel Patterson"
# [DETECTION] 01:04:57.881 — "Andrell Deangela Smith
# Magna Cum Laude"
# [DETECTION] 01:05:04.621 — "Jada Janese Johnson"
# [DETECTION] 01:05:48.198 — "Aaron Kawika Leonardo Crambert"
# [DETECTION] 01:05:53.236 — "Toby Lee McIntire"
# [DETECTION] 01:06:19.596 — "Luciana Theresa Credle
# Summa Cum Laude"
# [DETECTION] 01:06:25.168 — "Jacqueline Reese Wagner
# Magna Cum Laude"
# [DETECTION] 01:06:30.340 — "Olivia Newton Ortiz
# Magna Cum Laude"
# [DETECTION] 01:06:40.650 — "Nicholas Everhard"
# [DETECTION] 01:06:51.228 — "Emily Ann Ruger Lewis"
